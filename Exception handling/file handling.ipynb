# %% [markdown]
# ### WHAT IS FILE??
# *any name with extension (.py, .txt, .mp3, .c++) is a FILE.
# *when we want to handle these file we use file handling.
#
# # FILE HANDLING
# - it means doing CRUD (creating,reading,updating,deleting) opetions on file.
# - open() func is used to open file in python.

# %%
p = open('exception.ipynb')    #open in same directory, in other we have to wirte full address of directory.
print(p.read())
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "c66b6480",
#    "metadata": {},
#    "source": [
#     "## ERRORS\n",
#     "errors occur due to mistake in code that prevent it form running.these can be sytax aur logical error.\n",
#     "#### SYNTAX ERROR\n",
#     "- print('hello'     #not written closinf parenthesis\n",
#     "#### INDENTATION ERROR\n",
#     "- def animal():\n",
#     "print()             #not followed the correct indentation 4\n",
#     "\n",
#     "- error removing these three comes under Exception, these are handeled by user."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "17d44a37",
#    "metadata": {},
#    "source": [
#     "## EXCEPTION\n",
#     "- Exception are unexpected events or errors that occurs during the execution of program,disrupts the normal flow of program.\n",
#     " print('start')\n",
#     " print(10/0)        #raise ZeroDivisonError\n",
#     " print('end')       #this line will never run\n",
#     "\n",
# ...

# %%
r = open("superman.txt",'a')    #a append the new text in file . w overwrite the text

r.write ("i am a junior software developer engineer")

r.close()
